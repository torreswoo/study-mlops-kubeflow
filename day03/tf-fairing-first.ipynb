# %%
import tensorflow as tf
import os

# %%
def get_dataset():
    mnist = tf.keras.datasets.mnist

    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0
    return x_train, x_test, y_train, y_test

# %%
def train():
    
    x_train, x_test, y_train, y_test = get_dataset()
    model = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(28, 28)),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    model.fit(x_train, y_train, epochs=5)

    model.evaluate(x_test,  y_test, verbose=2)

# %%
namespace = 'koock'

# %%
if __name__ == '__main__':
    if os.getenv('FAIRING_RUNTIME',None):
        train()
    else:
        from kubeflow import fairing
        from kubeflow.fairing.kubernetes import utils as k8s_utils
        DOCKER_REGISTRY = "kubeflow-registry.default.svc.cluster.local:30000"
        filename = os.path.basename('first-tf-fairing.py')
        print("Executing {} remotely.".format(filename))
        fairing.config.set_preprocessor('notebook',
                                        notebook_file='first-tf-fairing.ipynb')
        fairing.config.set_builder('append',
                                   base_image='kubeflow-registry.default.svc.cluster.local:30000/kubeflow-jupyterlab:tf2.3-cpu',
                                   registry=DOCKER_REGISTRY,
                                   push=True)
        fairing.config.set_deployer('job',
                                   namespace='koock',
                                   pod_spec_mutators=[
                                       k8s_utils.get_resource_mutator(cpu=1,memory=2)])
        fairing.config.run()
# Out:
# [I 200924 05:30:38 config:134] Using preprocessor: <kubeflow.fairing.preprocessors.converted_notebook.ConvertNotebookPreprocessor object at 0x7efc69b6c860>
# [I 200924 05:30:38 config:136] Using builder: <kubeflow.fairing.builders.append.append.AppendBuilder object at 0x7efc69b6c898>
# [I 200924 05:30:38 config:138] Using deployer: <kubeflow.fairing.deployers.job.job.Job object at 0x7efc69b6c8d0>
# [W 200924 05:30:38 append:50] Building image using Append builder...
# [I 200924 05:30:38 base:107] Creating docker context: /tmp/fairing_context_0nszzkn7
# [I 200924 05:30:38 converted_notebook:127] Converting first-tf-fairing.ipynb to first-tf-fairing.py
# [I 200924 05:30:38 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/kubeflow-jupyterlab:tf2.3-cpu'
# Executing first-tf-fairing.py remotely.
# [W 200924 05:30:39 append:54] Image successfully built in 0.7334900690038921s.
# [W 200924 05:30:39 append:94] Pushing image kubeflow-registry.default.svc.cluster.local:30000/fairing-job:5259D8E...
# [I 200924 05:30:39 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/fairing-job:5259D8E'
# [W 200924 05:30:39 append:81] Uploading kubeflow-registry.default.svc.cluster.local:30000/fairing-job:5259D8E
# [I 200924 05:30:39 docker_session_:280] Layer sha256:2b0c22ff795d449839c81392de44b23b2f31b18696744480aa3835168bc088ef exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:65b3db15f518f11e53c95664d0675a5d78a5329d18d5316a406c2a45907a0723 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:a72a02a55e5c043c4e0c02b0e8fc5d57952be83e28b8d5111abbfa837dc8fa6b exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:efede69293d40574c55c651a5b7a2bf9ed487fa29a3ff0c25913e9245453028b exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:ddbebab167359b094e82650f6e3b7469387105a77a121c0fe203bd2fb5ac58fa exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:fef422dc3d908298b541031cf25510dd420d2b636d940aab277c4b8142e2bcea exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:162516aa9380468f03eb16eba673cdf6f1b2dbd679d946be3609e16cc89e68b4 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:2def44532935ecfdc600af37c2d2e3131d2e1dabc3a21a3e7fefa4bb751d7338 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:71e126169501d71bbbd0d3c8d9f35836c41660869fe8432ac606341ed21f7adb exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:8623dd73d22fa1b9277d2d27e6987437185e21f24a7319eeec739b62999aa62a exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:cb0d06c13dc639c061c93d5d523ec7c9a353f8681f6442eec0ade7e9050710ce exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:f355d2a41bb67030268a575f388f0b046b524f194ffe6bfe49c4c7b09847ca5a exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:57df1a1f1ad841deaf50c8f662d77e93b4b17af776ed66148116607f9aceffa8 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:2171e586617ffd23bd20b8351565f6e7cc8d23964a5e86163054a758770fc7c8 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:ff78e32c658ab641b46f8aebbd3a290c3b1cb7ba108fae7d30c20fb032a62861 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:03f1c9932170e54fface2382b2550b8052ae3d41f27e66ea1294e2055dd2b2e7 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:866aefa779b4a90e95e59ad3d3410446bdb9cb67e0d29d8bc55b712a13fe2bf5 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:929996ac2c7fdf4ac00185fc19406afec64472bb5574c5eb4d2682075d9ec452 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:9d9bb3e3e797e631610a6d9cb20cf529999b24946b3e53006e765788603185bf exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:850581be87f324c7b6f7d1c27b379793434517f3d4a5df97a9b859accbbaa7d0 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:3565026baf3518bacfcf949f35a64fadd9c6c3bfc0551a17ce6743377a62ae57 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:81e673dd72e62ab9f24089315a6d18461c5ea138776ca84f8d1cb1e3dd90191f exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:d0c5a0f9d9dd5076981ffa0516a8ed41beebd1ad0cbeac9e21b7c06e391d45d0 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:a717a819cd2afbfacf19d40fed9335e59fbc442db3992bb62a039edbcb267f94 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:dd2f0204312f1023b1eaea78b62a603bc070debea0859c366ab74336d2b3f837 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:8fea423e1867dca4ffa552384f895ee65dcbbf67a325f35f58f4534651f0d1b2 exists, skipping
# [I 200924 05:30:39 docker_session_:280] Layer sha256:1af28a55c3f320826db8df3146a2c198f9042877ef679f9e32210aa9a7fac9ef exists, skipping
# [I 200924 05:30:39 docker_session_:284] Layer sha256:268931159dd4a7a72cf916cffa85346581f1cf242e2b15011ba0fcf1a21d122a pushed.
# [I 200924 05:30:40 docker_session_:284] Layer sha256:b1df6f6e6732a599ef099a36e96525505b92c2e336356b32158f03f3af7bf5c0 pushed.
# [I 200924 05:30:40 docker_session_:334] Finished upload of: kubeflow-registry.default.svc.cluster.local:30000/fairing-job:5259D8E
# [W 200924 05:30:40 append:99] Pushed image kubeflow-registry.default.svc.cluster.local:30000/fairing-job:5259D8E in 1.4151377770031104s.
# [W 200924 05:30:40 job:101] The job fairing-job-zhl5p launched.
# [W 200924 05:30:41 manager:296] Waiting for fairing-job-zhl5p-zs49v to start...
# [W 200924 05:30:41 manager:296] Waiting for fairing-job-zhl5p-zs49v to start...
# [W 200924 05:30:41 manager:296] Waiting for fairing-job-zhl5p-zs49v to start...
# [W 200924 05:30:42 manager:296] Waiting for fairing-job-zhl5p-zs49v to start...
# [I 200924 05:30:44 manager:302] Pod started running True
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 2020-09-24 05:30:50.148778: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-09-24 05:30:50.154115: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2497105000 Hz
# 2020-09-24 05:30:50.154403: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56543bd10bd0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-09-24 05:30:50.154436: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-09-24 05:31:07.615841: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 188160000 exceeds 10% of free system memory.
# Epoch 1/5
#   95/1875 [>.............................] - ETA: 5s - loss: 1.0313 - accuracy: 0.69
#  218/1875 [==>...........................] - ETA: 5s - loss: 0.7171 - accuracy: 0.79
#  315/1875 [====>.........................] - ETA: 4s - loss: 0.6043 - accuracy: 0.82
#  427/1875 [=====>........................] - ETA: 4s - loss: 0.5371 - accuracy: 0.84
#  541/1875 [=======>......................] - ETA: 4s - loss: 0.4862 - accuracy: 0.85
#  670/1875 [=========>....................] - ETA: 3s - loss: 0.4474 - accuracy: 0.87
#  764/1875 [===========>..................] - ETA: 3s - loss: 0.4268 - accuracy: 0.87
#  885/1875 [=============>................] - ETA: 3s - loss: 0.4087 - accuracy: 0.88
# 1022/1875 [===============>..............] - ETA: 2s - loss: 0.3855 - accuracy: 0.88
# 1147/1875 [=================>............] - ETA: 2s - loss: 0.3670 - accuracy: 0.89
# 1264/1875 [==================>...........] - ETA: 2s - loss: 0.3528 - accuracy: 0.89
# 1355/1875 [====================>.........] - ETA: 1s - loss: 0.3400 - accuracy: 0.90
# 1445/1875 [======================>.......] - ETA: 1s - loss: 0.3315 - accuracy: 0.904
# 1539/1875 [=======================>......] - ETA: 1s - loss: 0.3220 - accuracy: 0.907
# 1653/1875 [=========================>....] - ETA: 0s - loss: 0.3139 - accuracy: 0.909
# 1789/1875 [===========================>..] - ETA: 0s - loss: 0.3057 - accuracy: 0.912
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2997 - accuracy: 0.9136
# Epoch 2/5
#   86/1875 [>.............................] - ETA: 5s - loss: 0.1763 - accuracy: 0.94
#  206/1875 [==>...........................] - ETA: 4s - loss: 0.1606 - accuracy: 0.95
#  334/1875 [====>.........................] - ETA: 4s - loss: 0.1676 - accuracy: 0.94
#  433/1875 [=====>........................] - ETA: 4s - loss: 0.1621 - accuracy: 0.95
#  528/1875 [=======>......................] - ETA: 4s - loss: 0.1613 - accuracy: 0.95
#  658/1875 [=========>....................] - ETA: 3s - loss: 0.1613 - accuracy: 0.95
#  754/1875 [===========>..................] - ETA: 3s - loss: 0.1592 - accuracy: 0.95
#  881/1875 [=============>................] - ETA: 3s - loss: 0.1585 - accuracy: 0.95
# 1000/1875 [===============>..............] - ETA: 2s - loss: 0.1566 - accuracy: 0.95
# 1136/1875 [=================>............] - ETA: 2s - loss: 0.1555 - accuracy: 0.95
# 1234/1875 [==================>...........] - ETA: 2s - loss: 0.1537 - accuracy: 0.95
# 1362/1875 [====================>.........] - ETA: 1s - loss: 0.1528 - accuracy: 0.95
# 1457/1875 [======================>.......] - ETA: 1s - loss: 0.1526 - accuracy: 0.954
# 1584/1875 [========================>.....] - ETA: 0s - loss: 0.1524 - accuracy: 0.954
# 1742/1875 [==========================>...] - ETA: 0s - loss: 0.1501 - accuracy: 0.955
# 1842/1875 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.955
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1484 - accuracy: 0.9558
# Epoch 3/5
#  116/1875 [>.............................] - ETA: 4s - loss: 0.1082 - accuracy: 0.9661
#  216/1875 [==>...........................] - ETA: 4s - loss: 0.1139 - accuracy: 0.964
#  352/1875 [====>.........................] - ETA: 4s - loss: 0.1141 - accuracy: 0.964
#  482/1875 [======>.......................] - ETA: 4s - loss: 0.1132 - accuracy: 0.964
#  585/1875 [========>.....................] - ETA: 3s - loss: 0.1114 - accuracy: 0.965
#  745/1875 [==========>...................] - ETA: 3s - loss: 0.1136 - accuracy: 0.964
#  845/1875 [============>.................] - ETA: 3s - loss: 0.1153 - accuracy: 0.96
#  972/1875 [==============>...............] - ETA: 2s - loss: 0.1141 - accuracy: 0.96
# 1068/1875 [================>.............] - ETA: 2s - loss: 0.1136 - accuracy: 0.96
# 1173/1875 [=================>............] - ETA: 2s - loss: 0.1143 - accuracy: 0.96
# 1306/1875 [===================>..........] - ETA: 1s - loss: 0.1132 - accuracy: 0.96
# 1402/1875 [=====================>........] - ETA: 1s - loss: 0.1132 - accuracy: 0.96
# 1527/1875 [=======================>......] - ETA: 1s - loss: 0.1133 - accuracy: 0.96
# 1639/1875 [=========================>....] - ETA: 0s - loss: 0.1119 - accuracy: 0.96
# 1738/1875 [==========================>...] - ETA: 0s - loss: 0.1117 - accuracy: 0.96
# 1849/1875 [============================>.] - ETA: 0s - loss: 0.1119 - accuracy: 0.96
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1117 - accuracy: 0.9658
# Epoch 4/5
#   85/1875 [>.............................] - ETA: 5s - loss: 0.0978 - accuracy: 0.97
#  223/1875 [==>...........................] - ETA: 4s - loss: 0.0889 - accuracy: 0.97
#  331/1875 [====>.........................] - ETA: 4s - loss: 0.0867 - accuracy: 0.97
#  427/1875 [=====>........................] - ETA: 4s - loss: 0.0884 - accuracy: 0.97
#  552/1875 [=======>......................] - ETA: 3s - loss: 0.0923 - accuracy: 0.97
#  658/1875 [=========>....................] - ETA: 3s - loss: 0.0911 - accuracy: 0.97
#  779/1875 [===========>..................] - ETA: 3s - loss: 0.0919 - accuracy: 0.97
#  918/1875 [=============>................] - ETA: 2s - loss: 0.0912 - accuracy: 0.97
# 1029/1875 [===============>..............] - ETA: 2s - loss: 0.0924 - accuracy: 0.97
# 1166/1875 [=================>............] - ETA: 2s - loss: 0.0925 - accuracy: 0.97
# 1268/1875 [===================>..........] - ETA: 1s - loss: 0.0936 - accuracy: 0.97
# 1397/1875 [====================>.........] - ETA: 1s - loss: 0.0932 - accuracy: 0.97
# 1467/1875 [======================>.......] - ETA: 1s - loss: 0.0937 - accuracy: 0.971
# 1597/1875 [========================>.....] - ETA: 0s - loss: 0.0936 - accuracy: 0.971
# 1720/1875 [==========================>...] - ETA: 0s - loss: 0.0925 - accuracy: 0.971
# 1815/1875 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.971
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0912 - accuracy: 0.9718
# Epoch 5/5
#   98/1875 [>.............................] - ETA: 5s - loss: 0.0714 - accuracy: 0.9792
#  206/1875 [==>...........................] - ETA: 5s - loss: 0.0716 - accuracy: 0.978
#  330/1875 [====>.........................] - ETA: 4s - loss: 0.0689 - accuracy: 0.978
#  440/1875 [======>.......................] - ETA: 4s - loss: 0.0716 - accuracy: 0.978
#  576/1875 [========>.....................] - ETA: 3s - loss: 0.0733 - accuracy: 0.978
#  679/1875 [=========>....................] - ETA: 3s - loss: 0.0738 - accuracy: 0.978
#  808/1875 [===========>..................] - ETA: 3s - loss: 0.0734 - accuracy: 0.97
#  942/1875 [==============>...............] - ETA: 2s - loss: 0.0740 - accuracy: 0.97
# 1074/1875 [================>.............] - ETA: 2s - loss: 0.0745 - accuracy: 0.97
# 1172/1875 [=================>............] - ETA: 2s - loss: 0.0747 - accuracy: 0.97
# 1298/1875 [===================>..........] - ETA: 1s - loss: 0.0736 - accuracy: 0.97
# 1365/1875 [====================>.........] - ETA: 1s - loss: 0.0730 - accuracy: 0.97
# 1474/1875 [======================>.......] - ETA: 1s - loss: 0.0730 - accuracy: 0.97
# 1597/1875 [========================>.....] - ETA: 0s - loss: 0.0734 - accuracy: 0.97
# 1700/1875 [==========================>...] - ETA: 0s - loss: 0.0735 - accuracy: 0.97
# 1825/1875 [============================>.] - ETA: 0s - loss: 0.0744 - accuracy: 0.97
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0745 - accuracy: 0.9776
# 313/313 - 1s - loss: 0.0743 - accuracy: 0.9767
# [W 200924 05:31:39 job:173] Cleaning up job fairing-job-zhl5p...
